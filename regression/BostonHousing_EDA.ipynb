# %%
import matplotlib.pyplot as plt #for plotting
import seaborn as sns #for plotting
import numpy as np #for data wrangling
import pandas as pd #for data wrangling 
import seaborn as sns

# %%
from sklearn.datasets import load_boston

# %%
dataset = load_boston()

# %%
dataset.data.shape
# Out:
# (506, 13)

# %%
dataset.feature_names
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
np.concatenate?

# %%
dataset.target.squeeze().shape
# Out:
# (506,)

# %%
df =pd.DataFrame(dataset.data, columns=dataset.feature_names)

# %%
df.corr().round(2).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_0f3de7fe_6c55_11e9_a8f5_f06e0be4c010row0_col0 {
#             background-color:  #023858;
#         }    #T_0f3de7fe_6c55_11e9_a8f5_f06e0be4c010row0_col1 {
#             background-color:  #d3d4e7;
#         }    #T_0f3de7fe_6c55_11e9_a8f5_f06e0be4c010row0_col2 {
#             background-color:  #2a88bc;
#         }    #T_0f3de7fe_6c55_11e9_a8f5_f06e0be4c010row0_col3 {
#             background-color:  #f7f0f7;
#         }    #T_0f3de7fe_6c55_11e9_a8f5_f06e0be4c010row0_col4 {
#             background-color:  #2383ba;
#         }    #T_0f3de7fe_6c55_11e9_a8f5_f06e0be4c010row0_col5 {
#             background-color:  #d2d2e7;
#         }    #T_0f3de7fe_6c55_11e9_a8f5_f06e0be4c010row0_col6 {
#             background-color:  #358fc0;
#         }    #T_0f3de7fe_6c55_11e9_a8f5_f06e0be4c010row0_col7 {
#             background-color:  #d7d6e9;
#         }    #T_0f3de7fe_6c55_11e9_a8f5_f06e0be4c010row0_col8 {
#             background-color:  #056faf;
# ...

# %%
a = pd.Series({'target':dataset.target})
type(a)
# Out:
# pandas.core.series.Series

# %%
pd.concat(df,pd.Series({'target':dataset.target}))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-4ea5ffabd44c> in <module>
# ----> 1 pd.concat(df,pd.Series({'target':dataset.target}))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     223                        keys=keys, levels=levels, names=names,
#     224                        verify_integrity=verify_integrity,
# --> 225                        copy=copy, sort=sort)
#     226     return op.get_result()
#     227
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     239             raise TypeError('first argument must be an iterable of pandas '
# ...

# %%
np.concatenate((dataset.data,dataset.target), axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-3dfa993acf39> in <module>
# ----> 1 np.concatenate((dataset.data,dataset.target), axis=1)
#
# ValueError: all the input arrays must have same number of dimensions

# %%
df = pd.DataFrame({'X': dataset.data, 'y':dataset.target})
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-10-686631ad06a0> in <module>
# ----> 1 df = pd.DataFrame({'X': dataset.data, 'y':dataset.target})
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     346                                  dtype=dtype, copy=copy)
#     347         elif isinstance(data, dict):
# --> 348             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     349         elif isinstance(data, ma.MaskedArray):
#     350             import numpy.ma.mrecords as mrecords
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _init_dict(self, data, index, columns, dtype)
#     457             arrays = [data[k] for k in keys]
#     458
# --> 459         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     460
# ...

# %%
from sklearn.datasets import load_boston
from sklearn.preprocessing import QuantileTransformer, quantile_transform

dataset = load_boston()
# target = np.array(dataset.feature_names) == "DIS"
target = dataset.target
# X = dataset.data[:, np.logical_not(target)]
X = dataset.data
# y = dataset.data[:, target].squeeze()
y = target.copy()
# y_trans = quantile_transform(dataset.data[:, target],
#                              output_distribution='normal').squeeze()
y_trans = quantile_transform(y.reshape(-1,1), output_distribution='normal').squeeze()

###############################################################################
# A :class:`sklearn.preprocessing.QuantileTransformer` is used such that the
# targets follows a normal distribution before applying a
# :class:`sklearn.linear_model.RidgeCV` model.

f, (ax0, ax1) = plt.subplots(1, 2)

ax0.hist(y, bins=100, **density_param)
ax0.set_ylabel('Probability')
ax0.set_xlabel('Target')
ax0.set_title('Target distribution')

ax1.hist(y_trans, bins=100, **density_param)
ax1.set_ylabel('Probability')
ax1.set_xlabel('Target')
ax1.set_title('Transformed target distribution')

f.suptitle("Boston housing data: distance to employment centers", y=0.035)
f.tight_layout(rect=[0.05, 0.05, 0.95, 0.95])

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

###############################################################################
# The effect of the transformer is weaker than on the synthetic data. However,
# the transform induces a decrease of the MAE.

f, (ax0, ax1) = plt.subplots(1, 2, sharey=True)

regr = RidgeCV()
regr.fit(X_train, y_train)
y_pred = regr.predict(X_test)

ax0.scatter(y_test, y_pred)
ax0.plot([0, 10], [0, 10], '--k')
ax0.set_ylabel('Target predicted')
ax0.set_xlabel('True Target')
ax0.set_title('Ridge regression \n without target transformation')
ax0.text(1, 9, r'$R^2$=%.2f, MAE=%.2f' % (
    r2_score(y_test, y_pred), median_absolute_error(y_test, y_pred)))
ax0.set_xlim([0, 10])
ax0.set_ylim([0, 10])

regr_trans = TransformedTargetRegressor(
    regressor=RidgeCV(),
    transformer=QuantileTransformer(output_distribution='normal'))
regr_trans.fit(X_train, y_train)
y_pred = regr_trans.predict(X_test)

ax1.scatter(y_test, y_pred)
ax1.plot([0, 10], [0, 10], '--k')
ax1.set_ylabel('Target predicted')
ax1.set_xlabel('True Target')
ax1.set_title('Ridge regression \n with target transformation')
ax1.text(1, 9, r'$R^2$=%.2f, MAE=%.2f' % (
    r2_score(y_test, y_pred), median_absolute_error(y_test, y_pred)))
ax1.set_xlim([0, 10])
ax1.set_ylim([0, 10])
